# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import numexpr as ne
import time
import copy
import sys

from tqdm import tqdm
from sklearn.metrics import accuracy_score, log_loss

import torch
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch.autograd import Variable

import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('../pytorch_utils/')
from utils import train, evaluate, get_data, top5_accuracy, per_class_accuracy, count_params

# %%
import torch.cuda
torch.cuda.is_available()
# Out:
# True

# %%
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # Load data

# %%
# %%time
X_train, X_val, Y_train, Y_val = get_data()
train_size = len(X_train)
val_size = len(X_val)
print(train_size, val_size)
# Out:
# 51200 5120
# CPU times: user 1min 31s, sys: 10.5 s, total: 1min 41s
# Wall time: 40.5 s

# %% [markdown]
# # Create iterators

# %%
val_data = TensorDataset(
    torch.FloatTensor(X_val), 
    torch.LongTensor(Y_val)
)

val_iterator = DataLoader(
    val_data, batch_size=64, shuffle=True, pin_memory=True
)

# %%
batch_size = 64

# %%
train_data = TensorDataset(
    torch.FloatTensor(X_train), 
    torch.LongTensor(Y_train)
)

train_iterator = DataLoader(
    train_data, batch_size=batch_size, shuffle=True, pin_memory=True
)

# %% [markdown]
# # Model

# %%
from model_resnet import make_model

# %%
model, criterion, optimizer = make_model()

# %%
count_params(model)
# Out:
# 21416000

# %% [markdown]
# # Train

# %%
n_epochs = 2
validation_step = 200
n_batches = int(np.ceil(train_size/batch_size))
M = 1
T = n_batches*n_epochs
initial = 0.01
n_batches
# Out:
# 800

# %%
def lr_scheduler(optimizer, step):
    
    global initial
    decay = np.cos(np.pi*((step - 1) % (T // M))/(T // M)) + 1.0
    
    for param_group in optimizer.param_groups:
        param_group['lr'] = initial*decay/2.0
    
    if (step - 1) % (T // M) == 0 and step != 1:
        # initial *= 0.5
        print('lr is reset:', initial)
        
    return optimizer

# %%
all_losses = []
all_models = []

# %%
# %%time
running_loss = 0.0
running_accuracy = 0.0 
start = time.time()
model.train()

for epoch in range(0, n_epochs):
    for step, (x_batch, y_batch) in enumerate(train_iterator, 1 + epoch*n_batches):
        
        optimizer = lr_scheduler(optimizer, step)
        batch_loss, batch_accuracy = train(
            model, criterion, optimizer, 
            x_batch, y_batch
        )
        running_loss += batch_loss
        running_accuracy += batch_accuracy
        
        if step % validation_step == 0:
            model.eval()
            test_loss, test_accuracy = evaluate(
                model, criterion, val_iterator
            )
            end = time.time()
            
            print('{0:.2f}  {1:.3f} {2:.3f}  {3:.3f} {4:.3f}  {5:.3f}'.format(
                step/n_batches, running_loss/validation_step, test_loss, 
                running_accuracy/validation_step, test_accuracy, end - start
            ))
            all_losses += [(
                step/n_batches,
                running_loss/validation_step, test_loss, 
                running_accuracy/validation_step, test_accuracy
            )] 
            
            running_loss = 0.0
            running_accuracy = 0.0 
            start = time.time()
            model.train()
            
        if step % (T // M) == 0:
            
            print('saving')
            model.cpu()
            clone = copy.deepcopy(model)
            all_models += [clone.state_dict()]
            model.cuda()
# Out:
# 0.25  2.583 1.217  0.530 0.735  53.455
# 0.50  0.995 0.917  0.800 0.787  52.445
# 0.75  0.767 0.838  0.846 0.795  52.638
# 1.00  0.645 0.824  0.877 0.811  52.825
# 1.25  0.467 0.763  0.928 0.839  52.929
# 1.50  0.440 0.730  0.936 0.826  52.865
# 1.75  0.419 0.735  0.941 0.828  52.946
# 2.00  0.400 0.730  0.948 0.836  53.038
# saving
# CPU times: user 6min 5s, sys: 57 s, total: 7min 2s
# Wall time: 7min 3s

# %% [markdown]
# # Loss/epoch

# %%
epochs = [x[0] for x in all_losses]
plt.plot(epochs, [x[1] for x in all_losses], label='train');
plt.plot(epochs, [x[2] for x in all_losses], label='test');
plt.legend();
plt.xlabel('epoch');
plt.ylabel('loss');

# %%
plt.plot(epochs, [x[3] for x in all_losses], label='train');
plt.plot(epochs, [x[4] for x in all_losses], label='test');
plt.legend();
plt.xlabel('epoch');
plt.ylabel('accuracy');

# %% [markdown]
# # Predict val. set

# %%
val_predictions = []

# %%
val_iterator_no_shuffle = DataLoader(
    val_data, batch_size=32, shuffle=False, pin_memory=True
)

# %%
# %%time
# model.load_state_dict(all_models[-1])
model.eval()

for x_batch, _ in val_iterator_no_shuffle:

    x_batch = Variable(x_batch.cuda(), volatile=True)
    logits = model(x_batch)

    # compute probabilities
    probs = F.softmax(logits) 
    val_predictions += [probs.cpu().data.numpy()]
# Out:
# CPU times: user 15.5 s, sys: 2.47 s, total: 18 s
# Wall time: 18.4 s

# %%
val_predictions = np.concatenate(val_predictions, axis=0)

# %%
accuracy_score(Y_val, val_predictions.argmax(1))
# Out:
# 0.830078125

# %%
log_loss(Y_val, val_predictions)
# Out:
# 0.74203356503817697

# %%
top5_accuracy(Y_val, val_predictions)
# Out:
# 0.95058593749999998

# %%
per_class_acc = per_class_accuracy(Y_val, val_predictions)
per_class_acc
# Out:
# array([ 0.85,  0.8 ,  0.75,  0.5 ,  0.8 ,  0.8 ,  0.75,  0.95,  0.95,
#         0.8 ,  1.  ,  0.9 ,  0.8 ,  1.  ,  0.95,  0.7 ,  0.75,  0.7 ,
#         0.85,  0.95,  0.8 ,  0.95,  1.  ,  0.9 ,  0.85,  0.6 ,  0.8 ,
#         0.9 ,  0.75,  0.65,  0.75,  0.85,  0.55,  0.85,  0.85,  0.9 ,
#         0.8 ,  0.75,  0.55,  0.9 ,  0.95,  0.75,  0.75,  0.7 ,  0.8 ,
#         0.9 ,  0.95,  0.8 ,  0.95,  0.8 ,  0.85,  0.85,  0.9 ,  0.85,
#         0.75,  0.65,  0.9 ,  0.8 ,  0.6 ,  0.45,  0.7 ,  0.95,  1.  ,
#         0.9 ,  0.9 ,  0.9 ,  0.85,  0.9 ,  0.8 ,  0.8 ,  0.85,  1.  ,
#         0.85,  0.65,  0.65,  0.95,  0.95,  0.7 ,  0.55,  0.55,  0.9 ,
#         0.75,  0.8 ,  1.  ,  0.75,  0.95,  0.8 ,  0.8 ,  0.8 ,  1.  ,
#         0.95,  0.9 ,  0.9 ,  0.95,  0.9 ,  0.85,  0.7 ,  0.9 ,  0.85,
#         0.95,  0.9 ,  0.95,  0.7 ,  0.9 ,  0.85,  0.9 ,  0.85,  0.75,
#         1.  ,  0.95,  0.95,  0.75,  0.85,  1.  ,  0.7 ,  0.9 ,  0.8 ,
#         1.  ,  0.8 ,  0.8 ,  1.  ,  0.7 ,  1.  ,  0.8 ,  0.55,  0.55,
#         0.9 ,  0.85,  1.  ,  0.95,  0.75,  0.9 ,  0.9 ,  0.9 ,  0.5 ,
#         0.85,  0.9 ,  0.95,  0.9 ,  0.9 ,  0.9 ,  1.  ,  0.85,  0.6 ,
#         1.  ,  0.75,  0.7 ,  0.5 ,  0.8 ,  0.9 ,  1.  ,  0.85,  0.7 ,
#         1.  ,  0.65,  0.85,  0.95,  0.9 ,  0.5 ,  0.8 ,  0.9 ,  0.65,
#         0.4 ,  0.95,  0.7 ,  0.9 ,  0.7 ,  1.  ,  0.7 ,  0.95,  0.8 ,
#         1.  ,  0.65,  0.9 ,  0.75,  0.9 ,  0.9 ,  0.95,  0.9 ,  0.55,
#         0.85,  1.  ,  0.9 ,  1.  ,  0.6 ,  1.  ,  0.75,  0.8 ,  0.9 ,
#         0.85,  0.45,  0.9 ,  0.8 ,  0.95,  0.65,  0.95,  0.8 ,  0.95,
#         0.65,  0.75,  1.  ,  0.75,  0.85,  1.  ,  0.8 ,  0.75,  0.75,
#         0.9 ,  0.5 ,  0.9 ,  0.65,  0.9 ,  0.9 ,  1.  ,  0.95,  0.9 ,
#         0.95,  0.95,  0.65,  1.  ,  0.95,  0.65,  0.8 ,  0.9 ,  0.95,
#         0.7 ,  0.9 ,  0.95,  0.75,  1.  ,  0.75,  0.95,  0.95,  0.8 ,
#         0.95,  0.95,  0.8 ,  0.9 ,  0.6 ,  0.95,  0.9 ,  0.85,  0.75,
#         0.7 ,  0.7 ,  0.7 ,  0.65,  0.85,  0.65,  1.  ,  0.9 ,  1.  ,
#         1.  ,  0.95,  0.6 ,  0.95])

# %% [markdown]
# # Error analysis

# %%
erroneous = Y_val != val_predictions.argmax(1)
n_errors = len(Y_val[erroneous])
n_errors
# Out:
# 870

# %%
to_show = np.random.choice(np.arange(0, n_errors), size=30, replace=False)

# %%
pictures = X_val[erroneous][to_show].copy()
pictures_predictions = val_predictions.argmax(1)[erroneous][to_show]
pictures_probs = val_predictions.max(1)[erroneous][to_show]
pictures_true = Y_val[erroneous][to_show]

# %%
mean = np.array([0.485, 0.456, 0.406], dtype='float32')
std = np.array([0.229, 0.224, 0.225], dtype='float32')
decode = np.load('../utils/decode.npy')[()]

# %%
pictures = np.transpose(pictures, axes=(0, 2, 3, 1))
ne.evaluate('pictures*std', out=pictures);
ne.evaluate('pictures + mean', out=pictures);

# %%
# show pictures, predicted classes and probabilities
_, axes = plt.subplots(nrows=6, ncols=5, figsize=(14, 16))
axes = axes.flatten()
for i, pic in enumerate(pictures):
    axes[i].set_axis_off();
    axes[i].imshow(pic);
    title = decode[pictures_predictions[i] + 1] + ' ' +\
        str(pictures_probs[i]) + '\ntrue: ' + decode[pictures_true[i] + 1]
    axes[i].set_title(title);
plt.tight_layout()

# %% [markdown]
# # Save the model

# %%
for i, m in enumerate(all_models):
    torch.save(m, 'model_state' + str(i) + '.pytorch')
